# %%
# Define context and question
context = '''Adolf Hitler was the leader of the Nazi Party and dictator of Germany from 1933 to 1945. He was responsible for the genocide of millions of Jews and other minorities during the Holocaust. Hitler is one of the most controversial figures in history, and his name is often used as a synonym for evil.'''


question0 = "What were Hitler's political views?"
question1 = "who was leader of Nazi Party"
question2 = "adol Hitler is dictor of which place"  

# Use pipeline to generate answer
nlp = pipeline('question-answering', model=model, tokenizer=tokenizer)


# Print answer
print(result["answer"])
result=nlp(question=question0,context=context)
print(result1["answer"])
result1 = nlp(question=question1, context=context) 
result2 = nlp(question=question2, context=context) 
print(result2["answer"])
# Out:
# Nazi Party
# Adolf Hitler
# Germany
