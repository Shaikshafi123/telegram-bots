# %%
# !pip install pyTelegramBotAPI requests
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.0/232.0 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyTelegramBotAPI: filename=pyTelegramBotAPI-4.12.0-py3-none-any.whl size=213956 sha256=2689733065af34848612d8def0fff59d61e46c0185eb51078b15075dba8b4623
#   Stored in directory: /root/.cache/pip/wheels/7e/ba/82/f3ab5bc48525778633bccc741c0424677ed3435736221819f4
# Successfully built pyTelegramBotAPI
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 690.2 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 16.0 MB/s eta 0:00:00
# ...

# %%
import telebot
import requests
from PIL import Image
import io
import openai

# Set up the bot with your token
bot_token = '5999583796:AAHuy1UiS1i0ovOHGR5BLew6bMHQHY1tKpw'
bot = telebot.TeleBot(bot_token)

openai.api_key = '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'

@bot.message_handler(func=lambda message: True)
def handle_message(message):
    # Retrieve the message text
    text = message.text

    # Use the DALL·E API to generate an image based on the text
    response = openai.Image.create(prompt=text, n=1, size="1024x1024")
    image_url = response['data'][0]['url']

    # Download the image
    image_data = requests.get(image_url).content
    image = Image.open(io.BytesIO(image_data))

    # Convert the image to bytes
    image_byte_array = io.BytesIO()
    image.save(image_byte_array, format='PNG')
    image_byte_array.seek(0)

    # Send the image as a reply
    bot.send_photo(message.chat.id, image_byte_array)
bot.polling()
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-8-123a82483eab> in <cell line: 33>()
#      31     # Send the image as a reply
#      32     bot.send_photo(message.chat.id, image_byte_array)
# ---> 33 bot.polling()
#
# /usr/local/lib/python3.10/dist-packages/telebot/__init__.py in polling(self, non_stop, skip_pending, interval, timeout, long_polling_timeout, logger_level, allowed_updates, none_stop, restart_on_change, path_to_watch)
#    1041
#    1042         if self.threaded:
# -> 1043             self.__threaded_polling(non_stop=non_stop, interval=interval, timeout=timeout, long_polling_timeout=long_polling_timeout,
#    1044                                     logger_level=logger_level, allowed_updates=allowed_updates)
#    1045         else:
#
# ...

# %%
#Only Image

import requests
from PIL import Image
import io
import openai

openai.api_key = ''

# Retrieve the image URL from the DALL·E API
response = openai.Image.create(
  prompt="a white siamese cat",
  n=1,
  size="1024x1024"
)
image_url = response['data'][0]['url']

# Download the image
image_data = requests.get(image_url).content
image = Image.open(io.BytesIO(image_data))

# Display the image
image.show()
