# %%
pip install python-nmap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for python-nmap: filename=python_nmap-0.7.1-py2.py3-none-any.whl size=20636 sha256=d3b4a7a20eadaedb5398b893ff0b017b286aa5845ddb377a307c8d92a82e8e92
#   Stored in directory: /root/.cache/pip/wheels/da/bd/c6/0342ac886d4deb8d166a3191eb2566f738c5b1574cb0a8cd62
# Successfully built python-nmap
# ...

# %%
import requests

def scan_url():
    # Prompt user to input the URL
    url = input("Enter the URL to scan: ")

    # Send a GET request to the URL
    response = requests.get(url)

    # Check the response status code
     if response.status_code == 200:
        print("URL is accessible")

        # Perform vulnerability scanning checks
        check_open_ports(url)
        check_ssl_vulnerabilities(url)
        check_web_application_vulnerabilities(url)

    else:
        print("URL is not accessible")

# Rest of the code...

# Example usage
scan_url()


def check_open_ports(url):
    # Implement your own logic to check for open ports
    # You can use libraries like 'nmap' or 'socket' to perform port scanning

    # Example: Perform port scanning using nmap library
    # Install 'python-nmap' library: pip install python-nmap
    import nmap

    nm = nmap.PortScanner()
    scan_results = nm.scan(url, arguments='-Pn -p 1-1000')

    # Process the scan results and print the open ports
    if 'scan' in scan_results.keys():
        for target_host in scan_results['scan'].keys():
            print(f"Open ports for {target_host}:")
            for protocol in scan_results['scan'][target_host].keys():
                ports = scan_results['scan'][target_host][protocol].keys()
                for port in ports:
                    state = scan_results['scan'][target_host][protocol][port]['state']
                    if state == 'open':
                        print(f"Port {port}/{protocol} is open")

def check_ssl_vulnerabilities(url):
    # Implement your own logic to check for SSL/TLS vulnerabilities
    # You can use libraries like 'sslscan' or 'nab' to perform SSL/TLS vulnerability scanning

    # Example: Perform SSL/TLS vulnerability scanning using sslscan command-line tool
    # Install 'sslscan' tool: sudo apt-get install sslscan
    import subprocess

    sslscan_output = subprocess.run(['sslscan', url], capture_output=True, text=True)

    # Process the sslscan output and print the vulnerabilities
    print("SSL/TLS vulnerabilities:")
    print(sslscan_output.stdout)

def check_web_application_vulnerabilities(url):
    # Implement your own logic to check for common web application vulnerabilities
    # You can use libraries like 'OWASP ZAP' or 'Nikto' to perform web application vulnerability scanning

    # Example: Perform web application vulnerability scanning using OWASP ZAP
    # Install 'OWASP ZAP' tool: https://www.zaproxy.org/download/
    import zapv2 as zap

    # Start the OWASP ZAP daemon
    zap_process = subprocess.Popen(['zap.sh', '-daemon'], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Connect to the OWASP ZAP API
    zap_proxy = {'http': 'http://localhost:8080', 'https': 'http://localhost:8080'}
    zap_api = zap.ZAPv2(proxies=zap_proxy)

    # Spider the target URL to discover web pages
    zap_api.spider.scan(url)

    # Wait until the spidering is complete
    while int(zap_api.spider.status()) < 100:
        time.sleep(2)

    # Perform active scanning on the discovered web pages
    zap_api.ascan.scan(url)

    # Wait until the active scanning is complete
# Out:
# Enter the URL to scan: https://www.shophive.com/
# URL is accessible
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-43b8e58ef71c> in <cell line: 25>()
#      23
#      24 # Example usage
# ---> 25 scan_url()
#      26
#      27
#
# <ipython-input-1-43b8e58ef71c> in scan_url()
#      13
#      14         # Perform vulnerability scanning checks
# ---> 15         check_open_ports(url)
#      16         check_ssl_vulnerabilities(url)
#      17         check_web_application_vulnerabilities(url)
#
# NameError: name 'check_open_ports' is not defined
